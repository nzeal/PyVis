# %%
import matplotlib.pyplot as plt
import numpy as np
import glob
import math
import pandas as pd


file = open("results.txt")

plt.figure(figsize=(16,10), dpi= 80)
plt.title("Benchmark STARWALL", fontsize=22)
plt.xlabel(r"Number runs", size=20)
plt.ylabel(r"Time spent [min]", size=20)

plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
plt.ylim(18, 35)

with open(files) as f:
    y = np.loadtxt(lines, dtype="float", comments="#", skiprows=1, unpack=True)
    ymax = max(y)
    plt.plot(y, color='tab:green', label='Peaks')
    
    
plt.savefig("/Users/nitshuklayahoo.com/Desktop/starwall.jpg")
